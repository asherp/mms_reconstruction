# %% [markdown]
# # Polynomial Reconstruction
#
# This tutorial demonstrates calling the Denton's Polynomial Reconstruction code to reproduce figures from Denton et al 2019.

# %%
cd ../AsherCode
# Out:
# /Users/apembrok/git/mms/AsherCode

# %%
from Denton import Denton

sDirData = "/Users/apembrok/git/mms/AsherCode/"

denton = Denton(sDirData=sDirData, solve = False)
denton
# Out:
# warning: Matlab-style short-circuit operation performed for operator &
# Denton([(lambdavec(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (lambdavec,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (xvec_1(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (xvec_1,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (xvec_2(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (xvec_2,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (xvec_3(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (xvec_3,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (xvec_4(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (xvec_4,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (evec_l(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (evec_l,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (evec_m(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (evec_m,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (evec_n(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (evec_n,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (Bvec_c(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (Bvec_c,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (Bvec_1(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (Bvec_1,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (Bvec_2(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (Bvec_2,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (Bvec_3(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (Bvec_3,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (Bvec_4(t),
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>),
#         (Bvec_4,
#          <function Denton.Denton.register_field.<locals>.f(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))>)])

# %% [markdown]
# ## Spacecraft positions

# %%
help(denton.xvec_1)
# Out:
# Help on function xvec_1 in module Denton:
#
# xvec_1(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))
#     position of MMS-1 in LMN coordinates
#
#     citation: Denton et al, 2019

# %% [markdown]
# From the docstring above, we read that xvec_1 is associated with the position of MMS-1 in LMN coordinates. We can retrieve these positions by calling the $\vec{x}_1(t)$ with its default argument for time.

# %%
denton.xvec_1().head()
# Out:
#                L         M         N
# 31.000 -0.226084 -0.429377  0.361654
# 31.001 -0.226085 -0.429377  0.361654
# 31.002 -0.226086 -0.429377  0.361655
# 31.003 -0.226087 -0.429377  0.361655
# 31.004 -0.226087 -0.429377  0.361655

# %% [markdown]
# We may also evaluate the positions at any other time within the default domain:

# %%
denton.xvec_1([33.1111, 34.1111])
# Out:
#                 L         M         N
# 33.1111 -0.226085 -0.429382  0.361671
# 34.1111 -0.226112 -0.429375  0.361666

# %% [markdown]
# ## Visualization
#
# To generate a graph of the first component of position, we'll first register a new function that extracts just the L component. Here we'll use python's `lambda` syntax so we can conveniently do this in one line.

# %%
denton['xvec_1_L'] = lambda t: denton.xvec_1(t).L

# %% [markdown]
# Now we can plot $\vec{x}_{1L}$ by specifying values for $t$:

# %%
fig = denton.plot(xvec_1_L = dict(t = denton.t))

# %% [markdown]
# We can then write the figure to file using plotly-orca.

# %%
import plotly.io as pio

pio.write_image(fig, '../docs/images/xvec_1_L.svg')

# %% [markdown]
# ![](images/xvec_1_L.svg?1 'alt text')

# %% [markdown]
# Alternatively, if you do not have plotly-orca installed, use plotly's iplot function, which also makes the graph interactive:

# %%
from plotly.offline import iplot
iplot(fig)
# Out:
# <div>
#
#
#             <div id="bc0927ab-0d44-4f85-859d-50eb8cf9812a" class="plotly-graph-div" style="height:400px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bc0927ab-0d44-4f85-859d-50eb8cf9812a")) {
#                     Plotly.newPlot(
#                         'bc0927ab-0d44-4f85-859d-50eb8cf9812a',
#                         [{"name": "xvec_1_L", "type": "scatter", "x": [31.000000000000004, 31.001, 31.002, 31.003000000000004, 31.004, 31.005, 31.006000000000004, 31.007, 31.008, 31.009000000000004, 31.01, 31.011, 31.012000000000004, 31.013, 31.014, 31.015000000000004, 31.016000000000002, 31.017, 31.018000000000004, 31.019000000000002, 31.02, 31.021000000000004, 31.022000000000002, 31.023, 31.024000000000004, 31.025000000000002, 31.026, 31.027000000000005, 31.028000000000002, 31.029, 31.030000000000005, 31.031000000000002, 31.032, 31.033000000000005, 31.034000000000002, 31.035, 31.036000000000005, 31.037000000000003, 31.038, 31.039000000000005, 31.040000000000003, 31.041, 31.042000000000005, 31.043000000000003, 31.044, 31.045000000000005, 31.046000000000003, 31.047, 31.048000000000005, 31.049000000000003, 31.05, 31.051000000000005, 31.052000000000003, 31.053, 31.054000000000006, 31.055000000000003, 31.056, 31.057000000000006, 31.058000000000003, 31.059, 31.060000000000006, 31.061000000000003, 31.062, 31.063, 31.064000000000004, 31.065, 31.066, 31.067000000000004, 31.068, 31.069, 31.070000000000004, 31.071, 31.072, 31.073000000000004, 31.074, 31.075, 31.076000000000004, 31.077, 31.078, 31.079000000000004, 31.080000000000002, 31.081, 31.082000000000004, 31.083000000000002, 31.084, 31.085000000000004, 31.086000000000002, 31.087, 31.088000000000005, 31.089000000000002, 31.09, 31.091000000000005, 31.092000000000002, 31.093, 31.094000000000005, 31.095000000000002, 31.096, 31.097000000000005, 31.098000000000003, 31.099, 31.100000000000005, 31.101000000000003, 31.102, 31.103000000000005, 31.104000000000003, 31.105, 31.106000000000005, 31.107000000000003, 31.108, 31.109000000000005, 31.110000000000003, 31.111, 31.112000000000005, 31.113000000000003, 31.114, 31.115000000000006, 31.116000000000003, 31.117, 31.118000000000006, 31.119000000000003, 31.12, 31.121000000000006, 31.122000000000003, 31.123, 31.124000000000006, 31.125000000000004, 31.126, 31.127, 31.128000000000004, 31.129, 31.13, 31.131000000000004, 31.132, 31.133, 31.134000000000004, 31.135, 31.136, 31.137000000000004, 31.138, 31.139, 31.140000000000004, 31.141000000000002, 31.142, 31.143000000000004, 31.144000000000002, 31.145, 31.146000000000004, 31.147000000000002, 31.148, 31.149000000000004, 31.150000000000002, 31.151, 31.152000000000005, 31.153000000000002, 31.154, 31.155000000000005, 31.156000000000002, 31.157, 31.158000000000005, 31.159000000000002, 31.16, 31.161000000000005, 31.162000000000003, 31.163, 31.164000000000005, 31.165000000000003, 31.166, 31.167000000000005, 31.168000000000003, 31.169, 31.170000000000005, 31.171000000000003, 31.172, 31.173000000000005, 31.174000000000003, 31.175, 31.176000000000005, 31.177000000000003, 31.178, 31.179000000000006, 31.180000000000003, 31.181, 31.182000000000006, 31.183000000000003, 31.184, 31.185000000000006, 31.186000000000003, 31.187, 31.188, 31.189000000000004, 31.19, 31.191, 31.192000000000004, 31.193, 31.194, 31.195000000000004, 31.196, 31.197, 31.198000000000004, 31.199, 31.2, 31.201000000000004, 31.202, 31.203, 31.204000000000004, 31.205000000000002, 31.206, 31.207000000000004, 31.208000000000002, 31.209, 31.210000000000004, 31.211000000000002, 31.212, 31.213000000000005, 31.214000000000002, 31.215, 31.216000000000005, 31.217000000000002, 31.218, 31.219000000000005, 31.220000000000002, 31.221, 31.222000000000005, 31.223000000000003, 31.224, 31.225000000000005, 31.226000000000003, 31.227, 31.228000000000005, 31.229000000000003, 31.23, 31.231000000000005, 31.232000000000003, 31.233, 31.234000000000005, 31.235000000000003, 31.236, 31.237000000000005, 31.238000000000003, 31.239, 31.240000000000006, 31.241000000000003, 31.242, 31.243000000000006, 31.244000000000003, 31.245, 31.246000000000006, 31.247000000000003, 31.248, 31.249000000000006, 31.250000000000004, 31.251, 31.252, 31.253000000000004, 31.254, 31.255, 31.256000000000004, 31.257, 31.258, 31.259000000000004, 31.26, 31.261, 31.262000000000004, 31.263, 31.264, 31.265000 ...

# %% [markdown]
# ## Eigenvalues

# %%
help(denton.lambdavec)
# Out:
# Help on function lambdavec in module Denton:
#
# lambdavec(t=array([31.   , 31.001, 31.002, ..., 35.498, 35.499, 35.5  ]))
#     MDD eigenvalues in L,M,N directions
#
#     citation: Denton et al, 2019

# %% [markdown]
# The first variable $\vec{\lambda}(t)$ represents the $MDD$ eigenvalues of field in $L,M,N$ directions. Each variable in the Kamodofied denton analysis tool has an associated docstring and citation. To see the results, we call $\vec{\lambda}(t)$ using its default argument for $t$.

# %%
# note head() is a pandas method that just shows the first 5 data points
denton.lambdavec().head()
# Out:
#                L         M         N
# 31.000  0.020128  0.000280  1.317018
# 31.001  0.017700  0.000281  1.317308
# 31.002  0.017108  0.000203  1.345510
# 31.003  0.016385  0.000365  1.359475
# 31.004  0.016297  0.000464  1.385793

# %% [markdown]
# Similar to above, we'll register a new function to plot just the L component.

# %%
denton['lambdavec_L'] = lambda t: denton.lambdavec(t).L

# %% [markdown]
# !!! note
#     The python `lambda` function should not to be confused with the eigenvalue function.

# %%
iplot(denton.plot(lambdavec_L = dict(t = denton.t)))
# Out:
# <div>
#
#
#             <div id="33001e75-e834-4695-bb05-bfa206bb9ab9" class="plotly-graph-div" style="height:400px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("33001e75-e834-4695-bb05-bfa206bb9ab9")) {
#                     Plotly.newPlot(
#                         '33001e75-e834-4695-bb05-bfa206bb9ab9',
#                         [{"name": "lambdavec_L", "type": "scatter", "x": [31.000000000000004, 31.001, 31.002, 31.003000000000004, 31.004, 31.005, 31.006000000000004, 31.007, 31.008, 31.009000000000004, 31.01, 31.011, 31.012000000000004, 31.013, 31.014, 31.015000000000004, 31.016000000000002, 31.017, 31.018000000000004, 31.019000000000002, 31.02, 31.021000000000004, 31.022000000000002, 31.023, 31.024000000000004, 31.025000000000002, 31.026, 31.027000000000005, 31.028000000000002, 31.029, 31.030000000000005, 31.031000000000002, 31.032, 31.033000000000005, 31.034000000000002, 31.035, 31.036000000000005, 31.037000000000003, 31.038, 31.039000000000005, 31.040000000000003, 31.041, 31.042000000000005, 31.043000000000003, 31.044, 31.045000000000005, 31.046000000000003, 31.047, 31.048000000000005, 31.049000000000003, 31.05, 31.051000000000005, 31.052000000000003, 31.053, 31.054000000000006, 31.055000000000003, 31.056, 31.057000000000006, 31.058000000000003, 31.059, 31.060000000000006, 31.061000000000003, 31.062, 31.063, 31.064000000000004, 31.065, 31.066, 31.067000000000004, 31.068, 31.069, 31.070000000000004, 31.071, 31.072, 31.073000000000004, 31.074, 31.075, 31.076000000000004, 31.077, 31.078, 31.079000000000004, 31.080000000000002, 31.081, 31.082000000000004, 31.083000000000002, 31.084, 31.085000000000004, 31.086000000000002, 31.087, 31.088000000000005, 31.089000000000002, 31.09, 31.091000000000005, 31.092000000000002, 31.093, 31.094000000000005, 31.095000000000002, 31.096, 31.097000000000005, 31.098000000000003, 31.099, 31.100000000000005, 31.101000000000003, 31.102, 31.103000000000005, 31.104000000000003, 31.105, 31.106000000000005, 31.107000000000003, 31.108, 31.109000000000005, 31.110000000000003, 31.111, 31.112000000000005, 31.113000000000003, 31.114, 31.115000000000006, 31.116000000000003, 31.117, 31.118000000000006, 31.119000000000003, 31.12, 31.121000000000006, 31.122000000000003, 31.123, 31.124000000000006, 31.125000000000004, 31.126, 31.127, 31.128000000000004, 31.129, 31.13, 31.131000000000004, 31.132, 31.133, 31.134000000000004, 31.135, 31.136, 31.137000000000004, 31.138, 31.139, 31.140000000000004, 31.141000000000002, 31.142, 31.143000000000004, 31.144000000000002, 31.145, 31.146000000000004, 31.147000000000002, 31.148, 31.149000000000004, 31.150000000000002, 31.151, 31.152000000000005, 31.153000000000002, 31.154, 31.155000000000005, 31.156000000000002, 31.157, 31.158000000000005, 31.159000000000002, 31.16, 31.161000000000005, 31.162000000000003, 31.163, 31.164000000000005, 31.165000000000003, 31.166, 31.167000000000005, 31.168000000000003, 31.169, 31.170000000000005, 31.171000000000003, 31.172, 31.173000000000005, 31.174000000000003, 31.175, 31.176000000000005, 31.177000000000003, 31.178, 31.179000000000006, 31.180000000000003, 31.181, 31.182000000000006, 31.183000000000003, 31.184, 31.185000000000006, 31.186000000000003, 31.187, 31.188, 31.189000000000004, 31.19, 31.191, 31.192000000000004, 31.193, 31.194, 31.195000000000004, 31.196, 31.197, 31.198000000000004, 31.199, 31.2, 31.201000000000004, 31.202, 31.203, 31.204000000000004, 31.205000000000002, 31.206, 31.207000000000004, 31.208000000000002, 31.209, 31.210000000000004, 31.211000000000002, 31.212, 31.213000000000005, 31.214000000000002, 31.215, 31.216000000000005, 31.217000000000002, 31.218, 31.219000000000005, 31.220000000000002, 31.221, 31.222000000000005, 31.223000000000003, 31.224, 31.225000000000005, 31.226000000000003, 31.227, 31.228000000000005, 31.229000000000003, 31.23, 31.231000000000005, 31.232000000000003, 31.233, 31.234000000000005, 31.235000000000003, 31.236, 31.237000000000005, 31.238000000000003, 31.239, 31.240000000000006, 31.241000000000003, 31.242, 31.243000000000006, 31.244000000000003, 31.245, 31.246000000000006, 31.247000000000003, 31.248, 31.249000000000006, 31.250000000000004, 31.251, 31.252, 31.253000000000004, 31.254, 31.255, 31.256000000000004, 31.257, 31.258, 31.259000000000004, 31.26, 31.261, 31.262000000000004, 31.263, 31.264, 31.265 ...
